# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import *

customers   = spark.read.option("header", True).csv("Files/Bronze/customers.csv")
orders      = spark.read.option("header", True).csv("Files/Bronze/orders.csv")
items       = spark.read.option("header", True).csv("Files/Bronze/order_items.csv")
products    = spark.read.option("header", True).csv("Files/Bronze/products.csv")
payments    = spark.read.option("header", True).csv("Files/Bronze/order_payments_dataset.csv")
reviews     = spark.read.option("header", True).csv("Files/Bronze/order_reviews.csv")
sellers     = spark.read.option("header", True).csv("Files/Bronze/sellers.csv")
geo         = spark.read.option("header", True).csv("Files/Bronze/geolocation.csv")
translation = spark.read.option("header", True).csv("Files/Bronze/product_category_name_translation.csv")
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 3, Finished, Available, Finished, False)

# %%
tables = {"customers": customers, "orders": orders, "items": items, "products": products,
          "payments": payments, "reviews": reviews, "sellers": sellers, "geo": geo,
          "translation": translation}

for name, df in tables.items():
    print(f"{name}: rows={df.count()}, columns={len(df.columns)}")
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 4, Finished, Available, Finished, False)
# customers: rows=99441, columns=5
# orders: rows=99441, columns=8
# items: rows=112650, columns=7
# products: rows=32951, columns=9
# payments: rows=103886, columns=5
# reviews: rows=104162, columns=7
# sellers: rows=3095, columns=4
# geo: rows=1000163, columns=5
# translation: rows=71, columns=2

# %%
customers.select([count(when(col(c).isNull(), c)).alias(c) for c in customers.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 5, Finished, Available, Finished, False)
# +-----------+------------------+------------------------+-------------+--------------+
# |customer_id|customer_unique_id|customer_zip_code_prefix|customer_city|customer_state|
# +-----------+------------------+------------------------+-------------+--------------+
# |          0|                 0|                       0|            0|             0|
# +-----------+------------------+------------------------+-------------+--------------+

# %%
orders.select([count(when(col(c).isNull(), c)).alias(c) for c in orders.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 6, Finished, Available, Finished, False)
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |order_id|customer_id|order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |       0|          0|           0|                       0|              160|                        1783|                         2965|                            0|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+

# %%
items.select([count(when(col(c).isNull(), c)).alias(c) for c in items.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 7, Finished, Available, Finished, False)
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |order_id|order_item_id|product_id|seller_id|shipping_limit_date|price|freight_value|
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |       0|            0|         0|        0|                  0|    0|            0|
# +--------+-------------+----------+---------+-------------------+-----+-------------+

# %%
products.select([count(when(col(c).isNull(), c)).alias(c) for c in products.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 8, Finished, Available, Finished, False)
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |         0|                  610|                610|                       610|               610|               2|                2|                2|               2|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+

# %%
payments.select([count(when(col(c).isNull(), c)).alias(c) for c in payments.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 9, Finished, Available, Finished, False)
# +--------+------------------+------------+--------------------+-------------+
# |order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------+------------------+------------+--------------------+-------------+
# |       0|                 0|           0|                   0|            0|
# +--------+------------------+------------+--------------------+-------------+

# %%
reviews.select([count(when(col(c).isNull(), c)).alias(c) for c in reviews.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 10, Finished, Available, Finished, False)
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |review_id|order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |        1|    2236|        2380|               92157|                 63079|                8764|                   8785|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+

# %%
sellers.select([count(when(col(c).isNull(), c)).alias(c) for c in sellers.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 11, Finished, Available, Finished, False)
# +---------+----------------------+-----------+------------+
# |seller_id|seller_zip_code_prefix|seller_city|seller_state|
# +---------+----------------------+-----------+------------+
# |        0|                     0|          0|           0|
# +---------+----------------------+-----------+------------+

# %%
geo.select([count(when(col(c).isNull(), c)).alias(c) for c in geo.columns]).show()
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 12, Finished, Available, Finished, False)
# +---------------------------+---------------+---------------+----------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat|geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+---------------+---------------+----------------+-----------------+
# |                          0|              0|              0|               0|                0|
# +---------------------------+---------------+---------------+----------------+-----------------+

# %%
for name, df in tables.items():
    total = df.count()
    unique = df.dropDuplicates().count()
    print(f"{name}: total={total}, unique={unique}, duplicates={total-unique}")
# Out:
# StatementMeta(, c95f1e97-e855-4c2b-af4a-0905f35f440d, 13, Finished, Available, Finished, False)
# customers: total=99441, unique=99441, duplicates=0
# orders: total=99441, unique=99441, duplicates=0
# items: total=112650, unique=112650, duplicates=0
# products: total=32951, unique=32951, duplicates=0
# payments: total=103886, unique=103886, duplicates=0
# reviews: total=104162, unique=104077, duplicates=85
# sellers: total=3095, unique=3095, duplicates=0
# geo: total=1000163, unique=738327, duplicates=261836
# translation: total=71, unique=71, duplicates=0
